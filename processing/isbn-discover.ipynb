# %%
import isbnDiscover




pdf = 'cover-samples/boler.pdf'

isbnDiscover.DEBUG = True
isbnDiscover.discover_isbn(pdf)
# Out:
# Эта книга принадлежит
# Контакты владельцаМатематическое
# мышлениеМатематическое  мышление
# Джо БоулерДжо БоулерКнига
# для родителей
# и учителейМатематика — это логика
# и умение видеть везде задачи.
# Математика — это совместные
# поиски нестандартных решений
# (и ошибки в этих поисках лишь
# развивают мозг).
# Математика — это красота
# закономерностей.
# Математику  можно преподавать
# так, что глаза учеников будут
# гореть. Убедитесь в этом сами.Математика — это тот предмет,
# который часто ненавидят школьники:
# маленькая ошибка в вычислениях
# перечеркивает все старания;
# к тому же существуют предубеждения
# насчет того, что не каждому дано
# преуспеть в математике.
# Джо Боулер, профессор
# Стэнфордского университета,
# предлагает совершенно другой взгляд
# на преподавание этой дисциплины.
# В ее методике математика — это
# не тоскливые цифры и заученные
# формулы. И не удел гениев-одиночек.
#
# Jo Boaler
# Mathematical
# Mindsets
# Unleashing Students’ Potential Through
# ...
