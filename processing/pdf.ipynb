# %%
path = 'cover-samples/teleskop.pdf'

# path = 'cover-samples/sobel.pdf'

path = 'cover-samples/plato.pdf'

path = 'cover-samples/relativity.pdf'

path = 'cover-samples/blinken.pdf'

path = 'cover-samples/boler.pdf'

path = 'cover-samples/manin.pdf'


import pdfBooks


texts = pdfBooks.pdf2text(path, pages_list=list(range(4)))

for idx, text in enumerate(texts):
    print('Page: ', idx)
    print(text)
    print()
    print()
# Out:
# Page:  0
#
#
#
# Page:  1
# Ю. И. Манин
# Математика
# как
# метафора
# Второе издание, дополненное
# Электронное издание
# Издательство МЦНМО
# Москва /uniF63A/uniF639/uniF6DC/uniF63C
#
#
# Page:  2
# УДК /uniF63D/uniF6DC(/uniF639/uniF6DC/uniF641)
# ББК /uniF63A/uniF63A./uniF6DCг
# M/uniF63A/uniF63B
# Манин Ю. И.
# Математика как метафора
# Электронное издание
# М.: МЦНМО, /uniF63A/uniF639/uniF6DC/uniF63C
# /uniF63C/uniF63A/uniF63C с.
# ISBN /uniF641/uniF63F/uniF640-/uniF63D-/uniF63C/uniF63C/uniF63B/uniF641-/uniF63A/uniF639/uniF63F/uniF63C-/uniF639
# В книге Ю. И. Манина собраны написанные и опубликованные в
# разные годы очерки по истории и философии математики и физик и,
# теории культуры и языка, а также впервые публикуемые отрывк и из
# воспоминаний, стихи и стихотворные переводы.
# Первое издание книги вышло в /uniF63A/uniF639/uniF639/uniF640 году.
# Подготовлено на основе книги: Манин Ю. И. Математика как метафора.
# ...

# %%
# Out:
# 430
# 1
# 2
# 3
# 4
# 5
# Ю. И. Манин
# Математика
# как
# метафора
# Второе издание, дополненное
# Электронное издание
# Издательство МЦНМО
# Москва /uniF63A/uniF639/uniF6DC/uniF63C
#
#
#
#
# УДК /uniF63D/uniF6DC(/uniF639/uniF6DC/uniF641)
# ББК /uniF63A/uniF63A./uniF6DCг
# M/uniF63A/uniF63B
# Манин Ю. И.
# Математика как метафора
# Электронное издание
# М.: МЦНМО, /uniF63A/uniF639/uniF6DC/uniF63C
# /uniF63C/uniF63A/uniF63C с.
# ISBN /uniF641/uniF63F/uniF640-/uniF63D-/uniF63C/uniF63C/uniF63B/uniF641-/uniF63A/uniF639/uniF63F/uniF63C-/uniF639
# В книге Ю. И. Манина собраны написанные и опубликованные в
# разные годы очерки по истории и философии математики и физик и,
# теории культуры и языка, а также впервые публикуемые отрывк и из
# воспоминаний, стихи и стихотворные переводы.
# Первое издание книги вышло в /uniF63A/uniF639/uniF639/uniF640 году.
# Подготовлено на основе книги: Манин Ю. И. Математика как метафора.
# ...
